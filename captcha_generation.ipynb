# %% [markdown]
# Computer Vision Project, Captcha-Recognition, mars-2025, Guyon Thomas, Poberay Bastien & Longeron Oriane, Centrale Lille

# %% [markdown]
# # CAPTCHA Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# CAPTCHAs (Completely Automated Public Turing test to tell Computers and Humans Apart) are widely used security measures designed to prevent automated bots from accessing online services. They typically involve recognizing distorted text, images, or solving interactive puzzles. While CAPTCHAs help protect websites, generating robust and diverse CAPTCHA samples is essential for training recognition models and improving security systems.
#
# This project focuses on using deep learning to generate synthetic CAPTCHA images. These generated CAPTCHAs can be used to test the effectiveness of machine learning models designed for CAPTCHA solving and security analysis.

# %% [markdown]
# - [1. Data preprocessing](#data-preprocessing)
# - [2. Encoding captcha labels](#encoding-captcha-labels)
# - [3. Conditional U-Net for image processing with conditional embeddings](#conditional-u-net-for-image-processing-with-conditional-embeddings)
# - [4. Training a conditional diffusion model for captcha generation](#training-a-conditional-diffusion-model-for-captcha-generation)

# %% [markdown]
# ## Import

# %%
# %pip install torch torchvision diffusers transformers accelerate

# %%
import os

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data preprocessing

# %%
# Folder containing captcha images
folder_path = "samples"

# Lists to store image paths and labels
image_paths = []
labels = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".png"):
        label = filename.split(".")[0]  # Extract label from filename
        label = label.upper()
        image_paths.append(os.path.join(folder_path, filename))
        labels.append(label)


# ----------- Test -----------
print("Image paths:", image_paths)
print("Labels:", labels)
# Out:
# Image paths: ['samples\\226md.png', 'samples\\22d5n.png', 'samples\\2356g.png', 'samples\\23mdg.png', 'samples\\23n88.png', 'samples\\243mm.png', 'samples\\244e2.png', 'samples\\245y5.png', 'samples\\24f6w.png', 'samples\\24pew.png', 'samples\\25257.png', 'samples\\253dc.png', 'samples\\25egp.png', 'samples\\25m6p.png', 'samples\\25p2m.png', 'samples\\25w53.png', 'samples\\264m5.png', 'samples\\268g2.png', 'samples\\28348.png', 'samples\\28x47.png', 'samples\\2b827.png', 'samples\\2bg48.png', 'samples\\2cegf.png', 'samples\\2cg58.png', 'samples\\2cgyx.png', 'samples\\2en7g.png', 'samples\\2enf4.png', 'samples\\2fxgd.png', 'samples\\2g783.png', 'samples\\2g7nm.png', 'samples\\2gyb6.png', 'samples\\2mg87.png', 'samples\\2mpnn.png', 'samples\\2n73f.png', 'samples\\2nbcx.png', 'samples\\2nf26.png', 'samples\\2npg6.png', 'samples\\2nx38.png', 'samples\\2p2y8.png', 'samples\\2pfpn.png', 'samples\\2w4y7.png', 'samples\\2wc38.png', 'samples\\2wx73.png', 'samples\\2x7bm.png', 'samples\\2xc2n.png', 'samples\\2ycn8.png', 'samples\\2yggg.png', 'samples\\325fb.png', 'samples\\32cnn.png', 'samples\\32dnn.png', 'samples\\33b22.png', 'samples\\33f7m.png', 'samples\\33n73.png', 'samples\\33ng4.png', 'samples\\33p4e.png', 'samples\\34b84.png', 'samples\\34fxm.png', 'samples\\34pcn.png', 'samples\\368y5.png', 'samples\\36bc2.png', 'samples\\36nx4.png', 'samples\

        self.image_paths = image_paths
        self.labels = labels
        self.transform = transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.ToTensor(),
            # Normalize to [-1, 1] if needed (depending on your model)
            transforms.Normalize([0.5], [0.5])
        ])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert("RGB")
        image = self.transform(image)
        label = self.labels[idx]  # assume label is a string, e.g., "A3B9Z"
        return image, label


# ----------- Test -----------
im_paths = ['samples\\226md.png', 'samples\\22d5n.png']
lbls = ["226MD", "22D5N"]
dataset = CaptchaDataset(im_paths, lbls)

# Load an image and its label
image, label = dataset[0]

print("Label:", label)
print("Image shape:", image.shape)  # (3, 64, 64) -> (channels, height, width)
# Out:
# Label: 226MD
# Image shape: torch.Size([3, 64, 64])

# %% [markdown]
# ## Encoding CAPTCHA Labels

# %% [markdown]
# The `LabelEmbedding` network is responsible for encoding textual labels into dense vector representations. It first transforms a sequence of character indices (representing a captcha label) into embeddings using an Embedding layer. Then, it uses an LSTM network to capture the sequential relationships between characters. The output is the last hidden state of the LSTM, which serves as a compact representation of the input label. This encoded information will later be used to condition the image generation process in the Conditional UNet.

# %%
class LabelEmbedding(nn.Module):
    def __init__(self, vocab_size, embedding_dim, max_length=5):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.max_length = max_length
        # Optionally, add an LSTM or transformer encoder for sequence encoding.
        self.encoder = nn.LSTM(embedding_dim, embedding_dim, batch_first=True)

    def forward(self, labels):
        # labels: (batch_size, max_length) of token indices
        x = self.embedding(labels)  # (batch_size, max_length, embedding_dim)
        # Encode sequence information. We take the last hidden state.
        _, (hidden, _) = self.encoder(x)
        return hidden.squeeze(0)  # (batch_size, embedding_dim)

# %% [markdown]
# ## Conditional U-Net for Image Processing with Conditional Embeddings

# %% [markdown]
# The `ConditionalUNet` is a deep convolutional network used for generating images conditioned on some additional information, in this case, the encoded label from LabelEmbedding. It follows the architecture of a standard UNet, which includes downsampling and upsampling layers. The key difference is that it is conditioned on a cond_embedding vector, which is passed into the network to influence the image generation. The network learns to reconstruct an image by removing noise step-by-step in a process called diffusion. During training, the network predicts the noise added to the image, progressively denoising it to generate realistic captcha images corresponding to the given label.

# %%
class ConditionalUNet(nn.Module):
    def __init__(self, in_channels=3, base_channels=64, cond_dim=128):
        super().__init__()
        # Downsample layers
        self.down1 = nn.Conv2d(in_channels, base_channels, kernel_size=3, padding=1)
        self.down2 = nn.Conv2d(base_channels, base_channels*2, kernel_size=3, padding=1)
        # Up-sample layers
        self.up1 = nn.ConvTranspose2d(base_channels*2, base_channels, kernel_size=3, padding=1)
        self.up2 = nn.ConvTranspose2d(base_channels, in_channels, kernel_size=3, padding=1)
        # Conditioning projection
        self.cond_proj = nn.Linear(cond_dim, base_channels*2)

    def forward(self, x, t, cond_embedding):
        """
        x: noisy image (B, C, H, W)
        t: timestep (for positional embedding if needed)
        cond_embedding: conditioning vector (B, cond_dim)
        """
        # Downsampling
        h1 = F.relu(self.down1(x))
        h2 = F.relu(self.down2(h1))
        
        # Inject conditioning: for example, add a broadcasted conditioning term.
        cond = self.cond_proj(cond_embedding).unsqueeze(-1).unsqueeze(-1)
        h2 = h2 + cond
        
        # Upsampling
        h = F.relu(self.up1(h2))
        # Optionally concatenate with h1 here for skip connections
        h = h + h1
        out = self.up2(h)
        return out

# %% [markdown]
# ## Training a Conditional Diffusion Model for CAPTCHA Generation

# %% [markdown]
# The noise schedule defines how noise is progressively added to the original image over multiple timesteps. At each timestep, the image becomes more corrupted, with the model learning to predict and reverse this noise to reconstruct the original image. The program uses a linear schedule for the noise levels, which gradually increases as the diffusion process progresses.

# %%
# Define a simple noise schedule
T = 1000  # total timesteps
betas = torch.linspace(1e-4, 0.02, T)  # or use a cosine schedule
alphas = 1.0 - betas
alphas_cumprod = torch.cumprod(alphas, dim=0)


def q_sample(x0, t, noise=None):
    """
    Forward diffusion: sample x_t from x0 using noise.
    x0: original image (B, C, H, W)
    t: timestep (B,)
    noise: optional noise sample
    """
    if noise is None:
        noise = torch.randn_like(x0)
    # Get appropriate alpha values
    alphas_t = alphas_cumprod[t].view(-1, 1, 1, 1).to(x0.device)
    return torch.sqrt(alphas_t) * x0 + torch.sqrt(1 - alphas_t) * noise

# %%
# Suppose we have:
cond_dim = 128  # dimension of text conditioning
unet = ConditionalUNet(in_channels=3, base_channels=64, cond_dim=cond_dim)
label_embedder = LabelEmbedding(vocab_size=36, embedding_dim=cond_dim, max_length=5)  
# For 26 letters + 10 digits = 36 tokens.

# %%
optimizer = torch.optim.Adam(list(unet.parameters()) + list(label_embedder.parameters()), lr=1e-4)

# %%
# Training loop skeleton
num_epochs = 100
dataloader = DataLoader(CaptchaDataset(image_paths, labels), batch_size=16, shuffle=True)


# ----------- Test -----------
# Display one captcha
for images, labels in dataloader:
    # Select the first image from the batch (index 0)
    image = images[0].clone() 
    image = image.permute(1, 2, 0)  # Convert to HWC for display (CHW to HWC)
    
    # Denormalize the image (scale back to [0, 1] range)
    image = (image + 1) / 2  # Since it was normalized with mean=0.5, std=0.5
    image = image.numpy()  # Convert tensor to numpy array

    plt.imshow(image)
    plt.title(f"Label: {labels[0]}")
    plt.axis('off')
    plt.show()

    break

# %%
def labels_to_indices(labels):
    """
    Convert a list of string labels to a tensor of indices.
    Assumes labels are strings of length 5 with characters in [0-9A-Z].
    """
    char_to_idx = {char: idx for idx, char in enumerate("0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ")}
    indices = [[char_to_idx[char] for char in label] for label in labels]
    return torch.tensor(indices, dtype=torch.long)

# %%
for epoch in range(num_epochs):
    for images, text_labels in tqdm(dataloader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
        # images: (B, 3, H, W)
        # Convert text_labels to indices, e.g., using your mapping.
        # Assume `labels_to_indices` converts list of 5-char strings to a tensor of shape (B, 5)
        label_indices = labels_to_indices(text_labels)  # Implement this function.
        cond_embedding = label_embedder(label_indices)  # (B, cond_dim)
        
        B = images.size(0)
        t = torch.randint(0, T, (B,), device=images.device).long()
        
        noise = torch.randn_like(images)
        x_t = q_sample(images, t, noise=noise)
        
        # The network tries to predict the noise added (this is one common formulation).
        predicted_noise = unet(x_t, t, cond_embedding)
        
        loss = F.mse_loss(predicted_noise, noise)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f"Epoch {epoch}: Loss = {loss.item()}")
# Out:
# Epoch 0: Loss = 0.38937100768089294
# Epoch 1: Loss = 0.2420637607574463
# Epoch 2: Loss = 0.3027302324771881
# Epoch 3: Loss = 0.17815160751342773
# Epoch 4: Loss = 0.1395585983991623
# Epoch 5: Loss = 0.21515963971614838
# Epoch 6: Loss = 0.1284937858581543
# Epoch 7: Loss = 0.14719147980213165
# Epoch 8: Loss = 0.07151757180690765
# Epoch 9: Loss = 0.13516782224178314
# Epoch 10: Loss = 0.14275558292865753
# Epoch 11: Loss = 0.06620700657367706
# Epoch 12: Loss = 0.16454075276851654
# Epoch 13: Loss = 0.15177439153194427
# Epoch 14: Loss = 0.06929060071706772
# Epoch 15: Loss = 0.0520474910736084
# Epoch 16: Loss = 0.07551658898591995
# Epoch 17: Loss = 0.16615253686904907
# Epoch 18: Loss = 0.07644344121217728
# Epoch 19: Loss = 0.07009628415107727
# Epoch 20: Loss = 0.09027242660522461
# Epoch 21: Loss = 0.07885230332612991
# Epoch 22: Loss = 0.050942543894052505
# Epoch 23: Loss = 0.05036360025405884
# Epoch 24: Loss = 0.050095412880182266
# Epoch 25: Loss = 0.15347068011760712
# Epoch 26: Loss = 0.09345779567956924
# Epoch 27: Loss = 0.047106627374887466
# Epoch 28: Loss = 0.04627304896712303
# Epoch 29: Loss = 0.06066545844078064
# Epoch 30: Loss = 0.04709794744849205
# Epoch 31: Loss = 0.03407252952456474
# Epoch 32: Loss = 0.07329282909631729
# Epoch 33: Loss = 0.053654298186302185
# Epoch 34: Loss = 0.05542357265949249
# Epoch 35: Loss = 0.05546035245060921
# Epoch 36: Loss = 0.0887284204363823
# Epoch 37: Loss = 0.03965219482779503
# Epoch 38: Loss = 0.1308559626340866
# Epoch 39: Loss = 0.04149670526385307
# Epoch 40: Loss = 0.04041895270347595
# Epoch 41: Loss = 0.055431608110666275
# Epoch 42: Loss = 0.053645044565200806
# Epoch 43: Loss = 0.04339848831295967
# Epoch 44: Loss = 0.05579128861427307
# Epoch 45: Loss = 0.038104016333818436
# Epoch 46: Loss = 0.05111802741885185
# Epoch 47: Loss = 0.05519813299179077
# Epoch 48: Loss = 0.04825952649116516
# Epoch 49: Loss = 0.05143539980053902
# Epoch 50: Loss = 0.04358026757836342
# Epoch 51: Loss = 0.03973023220896721
# Epoch 52: Loss = 0.09832432866096497
# Epoch 53: Loss = 0.0550055056810379
# Epoch 54: Loss = 0.04279347136616707
# Epoch 55: Loss = 0.09402534365653992
# Epoch 56: Loss = 0.1033250093460083
# Epoch 57: Loss = 0.03462149575352669
# Epoch 58: Loss = 0.035981301218271255
# Epoch 59: Loss = 0.057586420327425
# Epoch 60: Loss = 0.03142799437046051
# Epoch 61: Loss = 0.03555398806929588
# Epoch 62: Loss = 0.058319058269262314
# Epoch 63: Loss = 0.03392079100012779
# Epoch 64: Loss = 0.024295831099152565
# Epoch 65: Loss = 0.05363376811146736
# Epoch 66: Loss = 0.048685263842344284
# Epoch 67: Loss = 0.03781633824110031
# Epoch 68: Loss = 0.04206060990691185
# Epoch 69: Loss = 0.06781614571809769
# Epoch 70: Loss = 0.028444459661841393
# Epoch 71: Loss = 0.031194070354104042
# Epoch 72: Loss = 0.05049623176455498
# Epoch 73: Loss = 0.027148708701133728
# Epoch 74: Loss = 0.04752054437994957
# Epoch 75: Loss = 0.04721476137638092
# Epoch 76: Loss = 0.03401240333914757
# Epoch 77: Loss = 0.029709817841649055
# Epoch 78: Loss = 0.0321345329284668
# Epoch 79: Loss = 0.04066196456551552
# Epoch 80: Loss = 0.045877259224653244
# Epoch 81: Loss = 0.03134256228804588
# Epoch 82: Loss = 0.03291044756770134
# Epoch 83: Loss = 0.029001126065850258
# Epoch 84: Loss = 0.024646593257784843
# Epoch 85: Loss = 0.04171724244952202
# Epoch 86: Loss = 0.048440877348184586
# Epoch 87: Loss = 0.052601635456085205
# Epoch 88: Loss = 0.03376394137740135
# Epoch 89: Loss = 0.04450680688023567
# Epoch 90: Loss = 0.0319293811917305
# Epoch 91: Loss = 0.03249012678861618
# Epoch 92: Loss = 0.020225634798407555
# Epoch 93: Loss = 0.0735454186797142
# Epoch 94: Loss = 0.030429309234023094
# Epoch 95: Loss = 0.05206798389554024
# Epoch 96: Loss = 0.024646559730172157
# Epoch 97: Loss = 0.03495077043771744
# Epoch 98: Loss = 0.034750375896692276
# Epoch 99: Loss = 0.048236388713121414

# %%
@torch.no_grad()
def p_sample(model, x, t, cond_embedding):
    # In practice, you would use your learned model to predict the noise and then perform one reverse step.
    # Here, we use a simplified approach.
    predicted_noise = model(x, t, cond_embedding)
    beta_t = betas[t].view(-1, 1, 1, 1).to(x.device)
    alpha_t = alphas[t].view(-1, 1, 1, 1).to(x.device)
    alpha_cumprod_t = alphas_cumprod[t].view(-1, 1, 1, 1).to(x.device)
    
    # Compute the mean of the posterior (simplified)
    mean = (1 / torch.sqrt(alpha_t)) * (x - beta_t / torch.sqrt(1 - alpha_cumprod_t) * predicted_noise)
    # Sample noise if t > 0
    if t > 0:
        noise = torch.randn_like(x)
    else:
        noise = 0
    return mean + torch.sqrt(beta_t) * noise

@torch.no_grad()
def sample_captcha(model, label, label_embedder, shape=(1, 3, 64, 64)):
    # label: string (5 characters)a
    # Convert label to indices and get conditioning embedding.
    label_tensor = labels_to_indices([label])  # shape (1, 5)
    cond_embedding = label_embedder(label_tensor)
    
    x = torch.randn(shape).to(next(model.parameters()).device)  # start from pure noise
    
    for i in reversed(range(T)):
        t = torch.full((shape[0],), i, device=x.device, dtype=torch.long)
        x = p_sample(model, x, t, cond_embedding)
    return x

# Example usage after training:
generated = sample_captcha(unet, "A3B9Z", label_embedder)
# Post-process generated image: denormalize if needed, convert to PIL, etc.

# %%
image = generated[0].clone()
image = image.permute(1, 2, 0)  # Convert to HWC for display (CHW to HWC)

# Denormalize the image (scale back to [0, 1] range)
image = (image + 1) / 2  # Since it was normalized with mean=0.5, std=0.5
image = image.numpy()  # Convert tensor to numpy array

plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8597487..1.4333594].
